# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Itsbat Billah__

# %% [markdown]
# Wanna be a great data scientist in agricultural engineering field

# %% [markdown]
# _I am learning data science because it is broad subject, easy to understand, and can be useful combined with any other knowledge_

# %% [markdown]
# ### This Test Code is Just A Simple Math :)

# %%
1 * 1 / 1 + 1 - 1
# Out:
# 1.0

# %% [markdown]
# ***
# 3 keys to success in life :
# 1. Set Your Goals
# 2. Have Strong Belief System
# 3. Invest In Yourself
#
#
# ![key-to-success-in-life.webp](attachment:77657bc1-df00-43dc-8a9f-ac60bc9a9505.webp)
